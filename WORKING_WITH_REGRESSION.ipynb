# %% [markdown]
# <a href="https://colab.research.google.com/github/ozylily/myproject/blob/main/WORKING_WITH_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install scikit-learn

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df= pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/rideshare_2022.csv')
df.head(20)
# Out:
#                                      Trip ID Trip Start Timestamp  \
# 0   04767642defd6a3825d089ae66183906a89b902d     01/01/2022 00:00
# 1   138de88e19e045d9962f1f669e668f9dcdfbc9fd     01/01/2022 00:00
# 2   249cb7bc8eea309aaa3ef941756df4f62a53a92a     01/01/2022 00:00
# 3   36c8a2a4cd85fb32ae32170550d2a4d30b8df8a1     01/01/2022 00:00
# 4   493f7bbcba1d96bf10bd579fe1c4b7ddb95fd3a6     01/01/2022 00:00
# 5   5d07bc7d3534b93fd0c862b69b161857a6f43f52     01/01/2022 00:00
# 6   6d6bf89e407ba3d4a95681ea0dfa2e08d3a650cc     01/01/2022 00:00
# 7   7e0776ce5aed9c08fb7ae1366c267937c2101df4     01/01/2022 00:00
# 8   8e49900df0154a3f1fe40fdff266a11d01a7f121     01/01/2022 00:00
# 9   9c2ca52b0b8d0ef8e91a51f3f36b12ea9e0f883f     01/01/2022 00:00
# 10  af3dd79b10c8d9c5f4c6af6c95b7fa0078a00cf8     01/01/2022 00:00
# 11  be1aadeb82f5fb96fb05dfc8ff36a7908e529a44     01/01/2022 00:00
# 12  cf3718ce97733371720c9a924464ce2d3048fe52     01/01/2022 00:00
# ...

# %%
df= pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/rideshare_2022.csv')
clean=df. dropna()
clean.head(20)
# Out:
#                                      Trip ID Trip Start Timestamp  \
# 3   36c8a2a4cd85fb32ae32170550d2a4d30b8df8a1     01/01/2022 00:00
# 4   493f7bbcba1d96bf10bd579fe1c4b7ddb95fd3a6     01/01/2022 00:00
# 5   5d07bc7d3534b93fd0c862b69b161857a6f43f52     01/01/2022 00:00
# 8   8e49900df0154a3f1fe40fdff266a11d01a7f121     01/01/2022 00:00
# 11  be1aadeb82f5fb96fb05dfc8ff36a7908e529a44     01/01/2022 00:00
# 12  cf3718ce97733371720c9a924464ce2d3048fe52     01/01/2022 00:00
# 13  dfdde1bea88d9c49203a357b21cee91843b5eb2b     01/01/2022 00:00
# 15  00a10903a1dc2059e89f685a1a1e75089ab65f5a     01/01/2022 00:15
# 16  0975efcbf50a2da192b036ffd64eb6f325b8b2b9     01/01/2022 00:15
# 17  132ca4164f70de6aef8fcaf04499cc255bee895f     01/01/2022 00:15
# 18  1c68b3185559957a1a38a4ddad687b281bbbc64f     01/01/2022 00:15
# 19  265721ed24483894ce34e84fc4217d962476e58e     01/01/2022 00:15
# 21  394f379255c04bb9f8ed280a3b0fe5a17d91d5e9     01/01/2022 00:15
# ...

# %%
x= clean[['Trip Seconds']]
y= clean['Trip Miles']
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x= clean[['Trip Seconds']]
y= clean['Trip Miles']
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.2,random_state=42)
print(f"The dataset for train values are:{xtrain}")
# Out:
# The dataset for train values are:        Trip Seconds
# 414504         399.0
# 175954         541.0
# 206228         851.0
# 141471         540.0
# 431736        1891.0
# ...              ...
# 487564         726.0
# 682361         463.0
# 250192         776.0
# 277921         334.0
# 232284         463.0
#
# [296543 rows x 1 columns]

# %%
df= pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/rideshare_2022.csv')
df.head()
# Out:
#                                     Trip ID Trip Start Timestamp  \
# 0  04767642defd6a3825d089ae66183906a89b902d     01/01/2022 00:00
# 1  138de88e19e045d9962f1f669e668f9dcdfbc9fd     01/01/2022 00:00
# 2  249cb7bc8eea309aaa3ef941756df4f62a53a92a     01/01/2022 00:00
# 3  36c8a2a4cd85fb32ae32170550d2a4d30b8df8a1     01/01/2022 00:00
# 4  493f7bbcba1d96bf10bd579fe1c4b7ddb95fd3a6     01/01/2022 00:00
#
#   Trip End Timestamp  Trip Seconds  Trip Miles  Pickup Census Tract  \
# 0   01/01/2022 01:15        3905.0        44.5         1.703104e+10
# 1   01/01/2022 00:30        2299.0        25.0                  NaN
# 2   01/01/2022 00:00         275.0         1.5                  NaN
# 3   01/01/2022 00:15         243.0         1.0         1.703106e+10
# 4   01/01/2022 00:15         364.0         1.3         1.703107e+10
#
#    Dropoff Census Tract  Pickup Community Area  Dropoff Community Area  Fare  \
# 0                   NaN                    4.0                     NaN  55.0
# ...

# %%
df= pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/rideshare_2022.csv')
clean=df. dropna()
clean.head()
# Out:
#                                      Trip ID Trip Start Timestamp  \
# 3   36c8a2a4cd85fb32ae32170550d2a4d30b8df8a1     01/01/2022 00:00
# 4   493f7bbcba1d96bf10bd579fe1c4b7ddb95fd3a6     01/01/2022 00:00
# 5   5d07bc7d3534b93fd0c862b69b161857a6f43f52     01/01/2022 00:00
# 8   8e49900df0154a3f1fe40fdff266a11d01a7f121     01/01/2022 00:00
# 11  be1aadeb82f5fb96fb05dfc8ff36a7908e529a44     01/01/2022 00:00
#
#    Trip End Timestamp  Trip Seconds  Trip Miles  Pickup Census Tract  \
# 3    01/01/2022 00:15         243.0         1.0         1.703106e+10
# 4    01/01/2022 00:15         364.0         1.3         1.703107e+10
# 5    01/01/2022 00:15         467.0         2.2         1.703107e+10
# 8    01/01/2022 00:15         315.0         1.2         1.703184e+10
# 11   01/01/2022 00:15         964.0         1.5         1.703183e+10
#
#     Dropoff Census Tract  Pickup Community Area  Dropoff Community Area  Fare  \
# ...

# %%
x= clean[['Trip Seconds']]
y= clean['Trip Miles']
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x= clean[['Trip Seconds']]
y= clean['Trip Miles']
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.2,random_state=42)
print(f"The dataset for train values are:{xtrain}")
print(f"The dataset for train values are:{xtest}")
print(f"The dataset for train values are:{ytrain}")
print(f"The dataset for train values are:{ytest}")
# Out:
# The dataset for train values are:        Trip Seconds
# 414504         399.0
# 175954         541.0
# 206228         851.0
# 141471         540.0
# 431736        1891.0
# ...              ...
# 487564         726.0
# 682361         463.0
# 250192         776.0
# 277921         334.0
# 232284         463.0
#
# [296543 rows x 1 columns]
# The dataset for train values are:        Trip Seconds
# 238792         673.0
# 382830         637.0
# 477050         387.0
# 256720         880.0
# 505816        2848.0
# ...              ...
# 212407         554.0
# 524518         727.0
# 94730         1074.0
# 541659         508.0
# 624267         410.0
#
# [74136 rows x 1 columns]
# The dataset for train values are:414504    1.6
# 175954    2.7
# 206228    5.1
# 141471    1.5
# 431736    3.9
#          ...
# 487564    1.6
# 682361    1.5
# 250192    4.7
# 277921    1.4
# 232284    0.9
# Name: Trip Miles, Length: 296543, dtype: float64
# The dataset for train values are:238792     1.3
# ...

# %%
model= LinearRegression().fit (xtrain,ytrain)

# %%
ypredict= model.predict(xtest)
print (f'The predicted values are {ypredict}')
# Out:
# The predicted values are [3.20228651 2.97589265 1.40371308 ... 5.72406254 2.16464799 1.5483536 ]

# %%
ypredict= model.predict(xtest)
print(f'The independent values are {xtest}')
print (f'The predicted values are {ypredict}')
# Out:
# The independent values are         Trip Seconds
# 238792         673.0
# 382830         637.0
# 477050         387.0
# 256720         880.0
# 505816        2848.0
# ...              ...
# 212407         554.0
# 524518         727.0
# 94730         1074.0
# 541659         508.0
# 624267         410.0
#
# [74136 rows x 1 columns]
# The predicted values are [3.20228651 2.97589265 1.40371308 ... 5.72406254 2.16464799 1.5483536 ]

# %%
ypredict= model.predict(xtest)
print(f'The independent values are {xtest}')
print (f'The predicted values are {ypredict}')
# Out:
# The independent values are         Trip Seconds
# 238792         673.0
# 382830         637.0
# 477050         387.0
# 256720         880.0
# 505816        2848.0
# ...              ...
# 212407         554.0
# 524518         727.0
# 94730         1074.0
# 541659         508.0
# 624267         410.0
#
# [74136 rows x 1 columns]
# The predicted values are [3.20228651 2.97589265 1.40371308 ... 5.72406254 2.16464799 1.5483536 ]
